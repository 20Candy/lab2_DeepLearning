# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
iris = load_iris()

# %%
# Load data into a DataFrame
df = pd.DataFrame(iris.data, columns=iris.feature_names)
# Convert datatype to float
df = df.astype(float)
# append "target" and name it "label"
df['label'] = iris.target
# Use string label instead
df['label'] = df.label.replace(dict(enumerate(iris.target_names)))

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#          label
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica
#
# [150 rows x 5 columns]

# %%
# label -> one-hot encoding
label = pd.get_dummies(df['label'], prefix='label')
df = pd.concat([df, label], axis=1)
# drop old label
df.drop(['label'], axis=1, inplace=True)

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      label_setosa  label_versicolor  label_virginica
# 0            True             False            False
# 1            True             False            False
# 2            True             False            False
# 3            True             False            False
# 4            True             False            False
# ..            ...               ...              ...
# 145         False             False             True
# 146         False             False             True
# 147         False             False             True
# 148         False             False             True
# 149         False             False             True
#
# [150 rows x 7 columns]

# %%
# Creating X and y
X = df[['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']]
# Convert DataFrame into np array
X = np.asarray(X)
y = df[['label_setosa', 'label_versicolor', 'label_virginica']]
# Convert DataFrame into np array
y = np.asarray(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(
  X,
  y,
  test_size=0.20
)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization

# %%
batched_model = Sequential([
    Dense(64, input_shape=(4,), activation="relu"),
    BatchNormalization(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dense(3, activation='softmax')
]);

# %%
batched_model.compile(
    optimizer='adam', 
    loss='categorical_crossentropy', 
    metrics=['accuracy']
)

# %%
batched_history =  batched_model.fit(
    X_train, 
    y_train, 
    epochs=200, 
    validation_split=0.25, 
    batch_size=40, 
    verbose=2
)
# Out:
# Epoch 1/200
# 3/3 - 4s - loss: 1.0287 - accuracy: 0.4889 - val_loss: 1.0823 - val_accuracy: 0.3667 - 4s/epoch - 1s/step
# Epoch 2/200
# 3/3 - 0s - loss: 0.2390 - accuracy: 0.9556 - val_loss: 1.0646 - val_accuracy: 0.3667 - 64ms/epoch - 21ms/step
# Epoch 3/200
# 3/3 - 0s - loss: 0.1614 - accuracy: 0.9667 - val_loss: 1.0750 - val_accuracy: 0.3667 - 56ms/epoch - 19ms/step
# Epoch 4/200
# 3/3 - 0s - loss: 0.1112 - accuracy: 0.9778 - val_loss: 1.0841 - val_accuracy: 0.3667 - 56ms/epoch - 19ms/step
# Epoch 5/200
# 3/3 - 0s - loss: 0.1277 - accuracy: 0.9667 - val_loss: 1.0907 - val_accuracy: 0.3667 - 56ms/epoch - 19ms/step
# Epoch 6/200
# 3/3 - 0s - loss: 0.0473 - accuracy: 1.0000 - val_loss: 1.0921 - val_accuracy: 0.3667 - 57ms/epoch - 19ms/step
# Epoch 7/200
# 3/3 - 0s - loss: 0.0485 - accuracy: 0.9778 - val_loss: 1.0958 - val_accuracy: 0.3667 - 56ms/epoch - 19ms/step
# Epoch 8/200
# 3/3 - 0s - loss: 0.0848 - accuracy: 0.9667 - val_loss: 1.0999 - val_accuracy: 0.3667 - 53ms/epoch - 18ms/step
# Epoch 9/200
# 3/3 - 0s - loss: 0.0617 - accuracy: 0.9667 - val_loss: 1.0972 - val_accuracy: 0.3667 - 56ms/epoch - 19ms/step
# Epoch 10/200
# 3/3 - 0s - loss: 0.0372 - accuracy: 1.0000 - val_loss: 1.0902 - val_accuracy: 0.3667 - 56ms/epoch - 19ms/step
# Epoch 11/200
# 3/3 - 0s - loss: 0.0349 - accuracy: 0.9889 - val_loss: 1.0777 - val_accuracy: 0.3667 - 64ms/epoch - 21ms/step
# Epoch 12/200
# 3/3 - 0s - loss: 0.0274 - accuracy: 1.0000 - val_loss: 1.0718 - val_accuracy: 0.3667 - 56ms/epoch - 19ms/step
# Epoch 13/200
# 3/3 - 0s - loss: 0.0527 - accuracy: 0.9778 - val_loss: 1.0610 - val_accuracy: 0.3667 - 56ms/epoch - 19ms/step
# Epoch 14/200
# 3/3 - 0s - loss: 0.0545 - accuracy: 0.9889 - val_loss: 1.0562 - val_accuracy: 0.3667 - 56ms/epoch - 19ms/step
# Epoch 15/200
# 3/3 - 0s - loss: 0.0423 - accuracy: 0.9889 - val_loss: 1.0735 - val_accuracy: 0.3667 - 56ms/epoch - 19ms/step
# Epoch 16/200
# 3/3 - 0s - loss: 0.0783 - accuracy: 0.9667 - val_loss: 1.0890 - val_accuracy: 0.3667 - 56ms/epoch - 19ms/step
# Epoch 17/200
# 3/3 - 0s - loss: 0.0319 - accuracy: 1.0000 - val_loss: 1.0977 - val_accuracy: 0.3667 - 72ms/epoch - 24ms/step
# Epoch 18/200
# 3/3 - 0s - loss: 0.0446 - accuracy: 0.9889 - val_loss: 1.0955 - val_accuracy: 0.3667 - 64ms/epoch - 21ms/step
# Epoch 19/200
# 3/3 - 0s - loss: 0.0331 - accuracy: 1.0000 - val_loss: 1.0818 - val_accuracy: 0.3667 - 64ms/epoch - 21ms/step
# Epoch 20/200
# 3/3 - 0s - loss: 0.0590 - accuracy: 0.9889 - val_loss: 1.0654 - val_accuracy: 0.3667 - 64ms/epoch - 21ms/step
# Epoch 21/200
# 3/3 - 0s - loss: 0.0564 - accuracy: 0.9889 - val_loss: 1.0465 - val_accuracy: 0.3667 - 56ms/epoch - 19ms/step
# Epoch 22/200
# 3/3 - 0s - loss: 0.0469 - accuracy: 0.9889 - val_loss: 1.0280 - val_accuracy: 0.3667 - 64ms/epoch - 21ms/step
# Epoch 23/200
# 3/3 - 0s - loss: 0.0543 - accuracy: 0.9667 - val_loss: 1.0148 - val_accuracy: 0.3667 - 64ms/epoch - 21ms/step
# Epoch 24/200
# 3/3 - 0s - loss: 0.0307 - accuracy: 0.9889 - val_loss: 1.0019 - val_accuracy: 0.3667 - 64ms/epoch - 21ms/step
# Epoch 25/200
# 3/3 - 0s - loss: 0.0841 - accuracy: 0.9667 - val_loss: 0.9783 - val_accuracy: 0.3667 - 64ms/epoch - 21ms/step
# Epoch 26/200
# 3/3 - 0s - loss: 0.0220 - accuracy: 1.0000 - val_loss: 0.9488 - val_accuracy: 0.3667 - 56ms/epoch - 19ms/step
# Epoch 27/200
# 3/3 - 0s - loss: 0.0685 - accuracy: 0.9778 - val_loss: 0.9204 - val_accuracy: 0.4000 - 48ms/epoch - 16ms/step
# Epoch 28/200
# 3/3 - 0s - loss: 0.0743 - accuracy: 0.9556 - val_loss: 0.9005 - val_accuracy: 0.4667 - 56ms/epoch - 19ms/step
# Epoch 29/200
# 3/3 - 0s - loss: 0.0689 - accuracy: 0.9667 - val_loss: 0.8924 - val_accuracy: 0.4667 - 56ms/epoch - 19ms/step
# Epoch 30/200
# 3/3 - 0s - loss: 0.0535 - accuracy: 0.9889 - val_loss: 0.8845 - val_accuracy: 0.4667 - 56ms/epoch - 19ms/step
# Epoch 31/200
# 3/3 - 0s - loss: 0.0809 - accuracy: 0.9778 - val_loss: 0.8830 - val_accuracy: 0.4333 - 56ms/epoch - 19ms/step
# Epoch 32/200
# 3/3 - 0s - loss: 0.0924 - accuracy: 0.9667 - val_loss: 0.8863 - val_accuracy: 0.4000 - 64ms/epoch - 21ms/step
# Epoch 33/200
# 3/3 - 0s - loss: 0.0439 - accuracy: 0.9889 - val_loss: 0.8912 - val_accuracy: 0.4000 - 56ms/epoch - 19ms/step
# Epoch 34/200
# 3/3 - 0s - loss: 0.0561 - accuracy: 0.9778 - val_loss: 0.8942 - val_accuracy: 0.4333 - 48ms/epoch - 16ms/step
# Epoch 35/200
# 3/3 - 0s - loss: 0.0403 - accuracy: 1.0000 - val_loss: 0.8892 - val_accuracy: 0.4667 - 56ms/epoch - 19ms/step
# Epoch 36/200
# 3/3 - 0s - loss: 0.1089 - accuracy: 0.9556 - val_loss: 0.8566 - val_accuracy: 0.5000 - 56ms/epoch - 19ms/step
# Epoch 37/200
# 3/3 - 0s - loss: 0.1537 - accuracy: 0.9778 - val_loss: 0.8209 - val_accuracy: 0.6333 - 56ms/epoch - 19ms/step
# Epoch 38/200
# 3/3 - 0s - loss: 0.0455 - accuracy: 0.9889 - val_loss: 0.7864 - val_accuracy: 0.7667 - 56ms/epoch - 19ms/step
# Epoch 39/200
# 3/3 - 0s - loss: 0.0484 - accuracy: 0.9889 - val_loss: 0.7564 - val_accuracy: 0.8000 - 57ms/epoch - 19ms/step
# Epoch 40/200
# 3/3 - 0s - loss: 0.0360 - accuracy: 0.9889 - val_loss: 0.7281 - val_accuracy: 0.8000 - 64ms/epoch - 21ms/step
# Epoch 41/200
# 3/3 - 0s - loss: 0.0518 - accuracy: 0.9778 - val_loss: 0.6980 - val_accuracy: 0.8000 - 56ms/epoch - 19ms/step
# Epoch 42/200
# 3/3 - 0s - loss: 0.0420 - accuracy: 1.0000 - val_loss: 0.6627 - val_accuracy: 0.8000 - 56ms/epoch - 19ms/step
# Epoch 43/200
# 3/3 - 0s - loss: 0.0281 - accuracy: 1.0000 - val_loss: 0.6427 - val_accuracy: 0.7333 - 60ms/epoch - 20ms/step
# Epoch 44/200
# 3/3 - 0s - loss: 0.1142 - accuracy: 0.9778 - val_loss: 0.6272 - val_accuracy: 0.7333 - 60ms/epoch - 20ms/step
# Epoch 45/200
# 3/3 - 0s - loss: 0.0692 - accuracy: 0.9778 - val_loss: 0.6196 - val_accuracy: 0.7333 - 56ms/epoch - 19ms/step
# Epoch 46/200
# 3/3 - 0s - loss: 0.0222 - accuracy: 1.0000 - val_loss: 0.6135 - val_accuracy: 0.7333 - 64ms/epoch - 21ms/step
# Epoch 47/200
# 3/3 - 0s - loss: 0.0175 - accuracy: 1.0000 - val_loss: 0.6049 - val_accuracy: 0.7333 - 57ms/epoch - 19ms/step
# Epoch 48/200
# 3/3 - 0s - loss: 0.0165 - accuracy: 1.0000 - val_loss: 0.5924 - val_accuracy: 0.7333 - 57ms/epoch - 19ms/step
# Epoch 49/200
# 3/3 - 0s - loss: 0.0172 - accuracy: 1.0000 - val_loss: 0.5757 - val_accuracy: 0.7333 - 73ms/epoch - 24ms/step
# Epoch 50/200
# 3/3 - 0s - loss: 0.1095 - accuracy: 0.9556 - val_loss: 0.5470 - val_accuracy: 0.7333 - 72ms/epoch - 24ms/step
# Epoch 51/200
# 3/3 - 0s - loss: 0.0347 - accuracy: 0.9889 - val_loss: 0.5290 - val_accuracy: 0.8000 - 73ms/epoch - 24ms/step
# Epoch 52/200
# 3/3 - 0s - loss: 0.0374 - accuracy: 0.9889 - val_loss: 0.5076 - val_accuracy: 0.8000 - 55ms/epoch - 18ms/step
# Epoch 53/200
# 3/3 - 0s - loss: 0.0568 - accuracy: 0.9667 - val_loss: 0.4796 - val_accuracy: 0.8000 - 57ms/epoch - 19ms/step
# Epoch 54/200
# 3/3 - 0s - loss: 0.0492 - accuracy: 0.9889 - val_loss: 0.4488 - val_accuracy: 0.8000 - 65ms/epoch - 22ms/step
# Epoch 55/200
# 3/3 - 0s - loss: 0.0314 - accuracy: 0.9889 - val_loss: 0.4264 - val_accuracy: 0.8667 - 64ms/epoch - 21ms/step
# Epoch 56/200
# 3/3 - 0s - loss: 0.0295 - accuracy: 0.9889 - val_loss: 0.3997 - val_accuracy: 0.9333 - 59ms/epoch - 20ms/step
# Epoch 57/200
# 3/3 - 0s - loss: 0.0363 - accuracy: 0.9889 - val_loss: 0.3667 - val_accuracy: 0.9333 - 56ms/epoch - 19ms/step
# Epoch 58/200
# 3/3 - 0s - loss: 0.0329 - accuracy: 0.9778 - val_loss: 0.3490 - val_accuracy: 0.8667 - 66ms/epoch - 22ms/step
# Epoch 59/200
# 3/3 - 0s - loss: 0.0423 - accuracy: 0.9778 - val_loss: 0.3582 - val_accuracy: 0.8667 - 59ms/epoch - 20ms/step
# Epoch 60/200
# 3/3 - 0s - loss: 0.0396 - accuracy: 0.9778 - val_loss: 0.3773 - val_accuracy: 0.8333 - 59ms/epoch - 20ms/step
# Epoch 61/200
# 3/3 - 0s - loss: 0.0178 - accuracy: 1.0000 - val_loss: 0.3933 - val_accuracy: 0.8333 - 56ms/epoch - 19ms/step
# Epoch 62/200
# 3/3 - 0s - loss: 0.0444 - accuracy: 0.9778 - val_loss: 0.3916 - val_accuracy: 0.8333 - 56ms/epoch - 19ms/step
# Epoch 63/200
# 3/3 - 0s - loss: 0.0176 - accuracy: 1.0000 - val_loss: 0.3777 - val_accuracy: 0.8333 - 57ms/epoch - 19ms/step
# Epoch 64/200
# 3/3 - 0s - loss: 0.1170 - accuracy: 0.9333 - val_loss: 0.3662 - val_accuracy: 0.8333 - 60ms/epoch - 20ms/step
# Epoch 65/200
# 3/3 - 0s - loss: 0.0139 - accuracy: 1.0000 - val_loss: 0.3936 - val_accuracy: 0.8000 - 64ms/epoch - 21ms/step
# Epoch 66/200
# 3/3 - 0s - loss: 0.0231 - accuracy: 1.0000 - val_loss: 0.4089 - val_accuracy: 0.8000 - 56ms/epoch - 19ms/step
# Epoch 67/200
# 3/3 - 0s - loss: 0.0355 - accuracy: 0.9889 - val_loss: 0.4085 - val_accuracy: 0.8000 - 64ms/epoch - 21ms/step
# Epoch 68/200
# 3/3 - 0s - loss: 0.0579 - accuracy: 0.9667 - val_loss: 0.3931 - val_accuracy: 0.8000 - 64ms/epoch - 21ms/step
# Epoch 69/200
# 3/3 - 0s - loss: 0.0220 - accuracy: 1.0000 - val_loss: 0.3884 - val_accuracy: 0.8000 - 55ms/epoch - 18ms/step
# Epoch 70/200
# 3/3 - 0s - loss: 0.0246 - accuracy: 1.0000 - val_loss: 0.3835 - val_accuracy: 0.8000 - 56ms/epoch - 19ms/step
# Epoch 71/200
# 3/3 - 0s - loss: 0.0595 - accuracy: 0.9778 - val_loss: 0.3750 - val_accuracy: 0.8000 - 65ms/epoch - 22ms/step
# Epoch 72/200
# 3/3 - 0s - loss: 0.0171 - accuracy: 1.0000 - val_loss: 0.3633 - val_accuracy: 0.8000 - 56ms/epoch - 19ms/step
# Epoch 73/200
# 3/3 - 0s - loss: 0.0160 - accuracy: 1.0000 - val_loss: 0.3510 - val_accuracy: 0.8000 - 56ms/epoch - 19ms/step
# Epoch 74/200
# 3/3 - 0s - loss: 0.0247 - accuracy: 1.0000 - val_loss: 0.3297 - val_accuracy: 0.8333 - 64ms/epoch - 21ms/step
# Epoch 75/200
# 3/3 - 0s - loss: 0.0390 - accuracy: 0.9889 - val_loss: 0.2984 - val_accuracy: 0.8333 - 64ms/epoch - 21ms/step
# Epoch 76/200
# 3/3 - 0s - loss: 0.1192 - accuracy: 0.9556 - val_loss: 0.2519 - val_accuracy: 0.8333 - 60ms/epoch - 20ms/step
# Epoch 77/200
# 3/3 - 0s - loss: 0.0316 - accuracy: 0.9889 - val_loss: 0.2136 - val_accuracy: 0.9000 - 52ms/epoch - 17ms/step
# Epoch 78/200
# 3/3 - 0s - loss: 0.0724 - accuracy: 0.9778 - val_loss: 0.1944 - val_accuracy: 0.9000 - 56ms/epoch - 19ms/step
# Epoch 79/200
# 3/3 - 0s - loss: 0.0344 - accuracy: 0.9889 - val_loss: 0.2032 - val_accuracy: 0.9000 - 56ms/epoch - 19ms/step
# Epoch 80/200
# 3/3 - 0s - loss: 0.0999 - accuracy: 0.9667 - val_loss: 0.2343 - val_accuracy: 0.9000 - 64ms/epoch - 21ms/step
# Epoch 81/200
# 3/3 - 0s - loss: 0.1904 - accuracy: 0.9556 - val_loss: 0.2930 - val_accuracy: 0.8333 - 65ms/epoch - 22ms/step
# Epoch 82/200
# 3/3 - 0s - loss: 0.0392 - accuracy: 1.0000 - val_loss: 0.3129 - val_accuracy: 0.8000 - 62ms/epoch - 21ms/step
# Epoch 83/200
# 3/3 - 0s - loss: 0.1842 - accuracy: 0.9333 - val_loss: 0.3077 - val_accuracy: 0.8333 - 74ms/epoch - 25ms/step
# Epoch 84/200
# 3/3 - 0s - loss: 0.0713 - accuracy: 0.9667 - val_loss: 0.3023 - val_accuracy: 0.9333 - 58ms/epoch - 19ms/step
# Epoch 85/200
# 3/3 - 0s - loss: 0.0828 - accuracy: 0.9778 - val_loss: 0.2937 - val_accuracy: 0.9333 - 57ms/epoch - 19ms/step
# Epoch 86/200
# 3/3 - 0s - loss: 0.0662 - accuracy: 0.9889 - val_loss: 0.2909 - val_accuracy: 0.9333 - 56ms/epoch - 19ms/step
# Epoch 87/200
# 3/3 - 0s - loss: 0.0635 - accuracy: 0.9889 - val_loss: 0.2653 - val_accuracy: 0.9333 - 65ms/epoch - 22ms/step
# Epoch 88/200
# 3/3 - 0s - loss: 0.0488 - accuracy: 0.9889 - val_loss: 0.2259 - val_accuracy: 0.9667 - 58ms/epoch - 19ms/step
# Epoch 89/200
# 3/3 - 0s - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.2055 - val_accuracy: 0.9667 - 49ms/epoch - 16ms/step
# Epoch 90/200
# 3/3 - 0s - loss: 0.1213 - accuracy: 0.9667 - val_loss: 0.1897 - val_accuracy: 0.9667 - 65ms/epoch - 22ms/step
# Epoch 91/200
# 3/3 - 0s - loss: 0.0294 - accuracy: 1.0000 - val_loss: 0.1810 - val_accuracy: 0.9667 - 77ms/epoch - 26ms/step
# Epoch 92/200
# 3/3 - 0s - loss: 0.0578 - accuracy: 0.9889 - val_loss: 0.1771 - val_accuracy: 0.9667 - 61ms/epoch - 20ms/step
# Epoch 93/200
# 3/3 - 0s - loss: 0.1173 - accuracy: 0.9667 - val_loss: 0.1896 - val_accuracy: 0.9667 - 47ms/epoch - 16ms/step
# Epoch 94/200
# 3/3 - 0s - loss: 0.0305 - accuracy: 1.0000 - val_loss: 0.2148 - val_accuracy: 0.9333 - 46ms/epoch - 15ms/step
# Epoch 95/200
# 3/3 - 0s - loss: 0.0247 - accuracy: 1.0000 - val_loss: 0.2293 - val_accuracy: 0.9000 - 56ms/epoch - 19ms/step
# Epoch 96/200
# 3/3 - 0s - loss: 0.1231 - accuracy: 0.9556 - val_loss: 0.2375 - val_accuracy: 0.9000 - 75ms/epoch - 25ms/step
# Epoch 97/200
# 3/3 - 0s - loss: 0.0496 - accuracy: 0.9778 - val_loss: 0.2512 - val_accuracy: 0.9000 - 69ms/epoch - 23ms/step
# Epoch 98/200
# 3/3 - 0s - loss: 0.0509 - accuracy: 1.0000 - val_loss: 0.2441 - val_accuracy: 0.9000 - 64ms/epoch - 21ms/step
# Epoch 99/200
# 3/3 - 0s - loss: 0.0664 - accuracy: 0.9778 - val_loss: 0.2289 - val_accuracy: 0.9000 - 65ms/epoch - 22ms/step
# Epoch 100/200
# 3/3 - 0s - loss: 0.0301 - accuracy: 0.9889 - val_loss: 0.2128 - val_accuracy: 0.9000 - 56ms/epoch - 19ms/step
# Epoch 101/200
# 3/3 - 0s - loss: 0.0221 - accuracy: 1.0000 - val_loss: 0.1911 - val_accuracy: 0.9333 - 64ms/epoch - 21ms/step
# Epoch 102/200
# 3/3 - 0s - loss: 0.0478 - accuracy: 0.9889 - val_loss: 0.1756 - val_accuracy: 0.9333 - 76ms/epoch - 25ms/step
# Epoch 103/200
# 3/3 - 0s - loss: 0.0187 - accuracy: 0.9889 - val_loss: 0.1721 - val_accuracy: 0.9333 - 80ms/epoch - 27ms/step
# Epoch 104/200
# 3/3 - 0s - loss: 0.0179 - accuracy: 1.0000 - val_loss: 0.1729 - val_accuracy: 0.9333 - 72ms/epoch - 24ms/step
# Epoch 105/200
# 3/3 - 0s - loss: 0.0288 - accuracy: 0.9889 - val_loss: 0.1628 - val_accuracy: 0.9333 - 64ms/epoch - 21ms/step
# Epoch 106/200
# 3/3 - 0s - loss: 0.0689 - accuracy: 0.9889 - val_loss: 0.1594 - val_accuracy: 0.9333 - 69ms/epoch - 23ms/step
# Epoch 107/200
# 3/3 - 0s - loss: 0.0217 - accuracy: 0.9889 - val_loss: 0.1689 - val_accuracy: 0.9333 - 49ms/epoch - 16ms/step
# Epoch 108/200
# 3/3 - 0s - loss: 0.0713 - accuracy: 0.9778 - val_loss: 0.1740 - val_accuracy: 0.9333 - 70ms/epoch - 23ms/step
# Epoch 109/200
# 3/3 - 0s - loss: 0.0978 - accuracy: 0.9556 - val_loss: 0.1732 - val_accuracy: 0.9333 - 59ms/epoch - 20ms/step
# Epoch 110/200
# 3/3 - 0s - loss: 0.0159 - accuracy: 1.0000 - val_loss: 0.1734 - val_accuracy: 0.9667 - 81ms/epoch - 27ms/step
# Epoch 111/200
# 3/3 - 0s - loss: 0.0185 - accuracy: 1.0000 - val_loss: 0.1852 - val_accuracy: 0.9667 - 81ms/epoch - 27ms/step
# Epoch 112/200
# 3/3 - 0s - loss: 0.0156 - accuracy: 1.0000 - val_loss: 0.1956 - val_accuracy: 0.9667 - 90ms/epoch - 30ms/step
# Epoch 113/200
# 3/3 - 0s - loss: 0.0843 - accuracy: 0.9778 - val_loss: 0.1952 - val_accuracy: 0.9667 - 78ms/epoch - 26ms/step
# Epoch 114/200
# 3/3 - 0s - loss: 0.0533 - accuracy: 0.9889 - val_loss: 0.1994 - val_accuracy: 0.9667 - 72ms/epoch - 24ms/step
# Epoch 115/200
# 3/3 - 0s - loss: 0.0216 - accuracy: 0.9889 - val_loss: 0.2062 - val_accuracy: 0.9667 - 64ms/epoch - 21ms/step
# Epoch 116/200
# 3/3 - 0s - loss: 0.0192 - accuracy: 1.0000 - val_loss: 0.2072 - val_accuracy: 0.9333 - 66ms/epoch - 22ms/step
# Epoch 117/200
# 3/3 - 0s - loss: 0.0117 - accuracy: 1.0000 - val_loss: 0.2338 - val_accuracy: 0.9333 - 64ms/epoch - 21ms/step
# Epoch 118/200
# 3/3 - 0s - loss: 0.0235 - accuracy: 1.0000 - val_loss: 0.2609 - val_accuracy: 0.9333 - 72ms/epoch - 24ms/step
# Epoch 119/200
# 3/3 - 0s - loss: 0.0117 - accuracy: 1.0000 - val_loss: 0.2818 - val_accuracy: 0.9333 - 73ms/epoch - 24ms/step
# Epoch 120/200
# 3/3 - 0s - loss: 0.0620 - accuracy: 0.9889 - val_loss: 0.3095 - val_accuracy: 0.9333 - 73ms/epoch - 24ms/step
# Epoch 121/200
# 3/3 - 0s - loss: 0.0387 - accuracy: 0.9889 - val_loss: 0.3534 - val_accuracy: 0.8667 - 71ms/epoch - 24ms/step
# Epoch 122/200
# 3/3 - 0s - loss: 0.0379 - accuracy: 0.9889 - val_loss: 0.3299 - val_accuracy: 0.9000 - 73ms/epoch - 24ms/step
# Epoch 123/200
# 3/3 - 0s - loss: 0.0801 - accuracy: 0.9778 - val_loss: 0.2896 - val_accuracy: 0.9000 - 80ms/epoch - 27ms/step
# Epoch 124/200
# 3/3 - 0s - loss: 0.0757 - accuracy: 0.9778 - val_loss: 0.2376 - val_accuracy: 0.9667 - 64ms/epoch - 21ms/step
# Epoch 125/200
# 3/3 - 0s - loss: 0.0722 - accuracy: 0.9667 - val_loss: 0.2110 - val_accuracy: 0.9667 - 80ms/epoch - 27ms/step
# Epoch 126/200
# 3/3 - 0s - loss: 0.0609 - accuracy: 0.9667 - val_loss: 0.2049 - val_accuracy: 0.9667 - 68ms/epoch - 23ms/step
# Epoch 127/200
# 3/3 - 0s - loss: 0.0368 - accuracy: 0.9889 - val_loss: 0.2349 - val_accuracy: 0.9333 - 72ms/epoch - 24ms/step
# Epoch 128/200
# 3/3 - 0s - loss: 0.0420 - accuracy: 0.9889 - val_loss: 0.2513 - val_accuracy: 0.9333 - 64ms/epoch - 21ms/step
# Epoch 129/200
# 3/3 - 0s - loss: 0.0419 - accuracy: 0.9889 - val_loss: 0.2385 - val_accuracy: 0.9000 - 67ms/epoch - 22ms/step
# Epoch 130/200
# 3/3 - 0s - loss: 0.0869 - accuracy: 0.9778 - val_loss: 0.3502 - val_accuracy: 0.8667 - 56ms/epoch - 19ms/step
# Epoch 131/200
# 3/3 - 0s - loss: 0.0509 - accuracy: 0.9778 - val_loss: 0.4179 - val_accuracy: 0.8667 - 55ms/epoch - 18ms/step
# Epoch 132/200
# 3/3 - 0s - loss: 0.0226 - accuracy: 1.0000 - val_loss: 0.3174 - val_accuracy: 0.8667 - 72ms/epoch - 24ms/step
# Epoch 133/200
# 3/3 - 0s - loss: 0.0254 - accuracy: 1.0000 - val_loss: 0.2478 - val_accuracy: 0.9000 - 72ms/epoch - 24ms/step
# Epoch 134/200
# 3/3 - 0s - loss: 0.0437 - accuracy: 1.0000 - val_loss: 0.2292 - val_accuracy: 0.9333 - 66ms/epoch - 22ms/step
# Epoch 135/200
# 3/3 - 0s - loss: 0.0398 - accuracy: 0.9889 - val_loss: 0.2202 - val_accuracy: 0.9333 - 64ms/epoch - 21ms/step
# Epoch 136/200
# 3/3 - 0s - loss: 0.0276 - accuracy: 1.0000 - val_loss: 0.1987 - val_accuracy: 0.9333 - 55ms/epoch - 18ms/step
# Epoch 137/200
# 3/3 - 0s - loss: 0.0279 - accuracy: 1.0000 - val_loss: 0.1824 - val_accuracy: 0.9333 - 72ms/epoch - 24ms/step
# Epoch 138/200
# 3/3 - 0s - loss: 0.0299 - accuracy: 1.0000 - val_loss: 0.1727 - val_accuracy: 0.9333 - 70ms/epoch - 23ms/step
# Epoch 139/200
# 3/3 - 0s - loss: 0.0214 - accuracy: 1.0000 - val_loss: 0.1714 - val_accuracy: 0.9333 - 80ms/epoch - 27ms/step
# Epoch 140/200
# 3/3 - 0s - loss: 0.0161 - accuracy: 1.0000 - val_loss: 0.1741 - val_accuracy: 0.9333 - 66ms/epoch - 22ms/step
# Epoch 141/200
# 3/3 - 0s - loss: 0.0890 - accuracy: 0.9667 - val_loss: 0.1692 - val_accuracy: 0.9333 - 72ms/epoch - 24ms/step
# Epoch 142/200
# 3/3 - 0s - loss: 0.0306 - accuracy: 0.9889 - val_loss: 0.1841 - val_accuracy: 0.9333 - 56ms/epoch - 19ms/step
# Epoch 143/200
# 3/3 - 0s - loss: 0.0362 - accuracy: 0.9889 - val_loss: 0.2109 - val_accuracy: 0.9333 - 64ms/epoch - 21ms/step
# Epoch 144/200
# 3/3 - 0s - loss: 0.0299 - accuracy: 0.9889 - val_loss: 0.2261 - val_accuracy: 0.9333 - 69ms/epoch - 23ms/step
# Epoch 145/200
# 3/3 - 0s - loss: 0.0299 - accuracy: 0.9889 - val_loss: 0.2312 - val_accuracy: 0.9333 - 56ms/epoch - 19ms/step
# Epoch 146/200
# 3/3 - 0s - loss: 0.0300 - accuracy: 1.0000 - val_loss: 0.2679 - val_accuracy: 0.9333 - 62ms/epoch - 21ms/step
# Epoch 147/200
# 3/3 - 0s - loss: 0.0709 - accuracy: 0.9889 - val_loss: 0.3391 - val_accuracy: 0.9000 - 72ms/epoch - 24ms/step
# Epoch 148/200
# 3/3 - 0s - loss: 0.0161 - accuracy: 1.0000 - val_loss: 0.3799 - val_accuracy: 0.8667 - 71ms/epoch - 24ms/step
# Epoch 149/200
# 3/3 - 0s - loss: 0.0314 - accuracy: 0.9889 - val_loss: 0.3665 - val_accuracy: 0.8667 - 72ms/epoch - 24ms/step
# Epoch 150/200
# 3/3 - 0s - loss: 0.0606 - accuracy: 0.9778 - val_loss: 0.2951 - val_accuracy: 0.9000 - 66ms/epoch - 22ms/step
# Epoch 151/200
# 3/3 - 0s - loss: 0.0116 - accuracy: 1.0000 - val_loss: 0.2128 - val_accuracy: 0.9000 - 72ms/epoch - 24ms/step
# Epoch 152/200
# 3/3 - 0s - loss: 0.0180 - accuracy: 1.0000 - val_loss: 0.1720 - val_accuracy: 0.9333 - 66ms/epoch - 22ms/step
# Epoch 153/200
# 3/3 - 0s - loss: 0.0182 - accuracy: 1.0000 - val_loss: 0.1490 - val_accuracy: 0.9333 - 50ms/epoch - 17ms/step
# Epoch 154/200
# 3/3 - 0s - loss: 0.0274 - accuracy: 1.0000 - val_loss: 0.1358 - val_accuracy: 0.9333 - 67ms/epoch - 22ms/step
# Epoch 155/200
# 3/3 - 0s - loss: 0.0176 - accuracy: 1.0000 - val_loss: 0.1291 - val_accuracy: 0.9333 - 63ms/epoch - 21ms/step
# Epoch 156/200
# 3/3 - 0s - loss: 0.0302 - accuracy: 0.9889 - val_loss: 0.1542 - val_accuracy: 0.9000 - 65ms/epoch - 22ms/step
# Epoch 157/200
# 3/3 - 0s - loss: 0.0598 - accuracy: 0.9778 - val_loss: 0.2008 - val_accuracy: 0.9000 - 72ms/epoch - 24ms/step
# Epoch 158/200
# 3/3 - 0s - loss: 0.0161 - accuracy: 1.0000 - val_loss: 0.2698 - val_accuracy: 0.8667 - 72ms/epoch - 24ms/step
# Epoch 159/200
# 3/3 - 0s - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.3245 - val_accuracy: 0.8667 - 72ms/epoch - 24ms/step
# Epoch 160/200
# 3/3 - 0s - loss: 0.0364 - accuracy: 0.9778 - val_loss: 0.3415 - val_accuracy: 0.8667 - 65ms/epoch - 22ms/step
# Epoch 161/200
# 3/3 - 0s - loss: 0.0735 - accuracy: 0.9667 - val_loss: 0.3209 - val_accuracy: 0.8667 - 79ms/epoch - 26ms/step
# Epoch 162/200
# 3/3 - 0s - loss: 0.0482 - accuracy: 0.9778 - val_loss: 0.2891 - val_accuracy: 0.9000 - 72ms/epoch - 24ms/step
# Epoch 163/200
# 3/3 - 0s - loss: 0.0176 - accuracy: 1.0000 - val_loss: 0.2085 - val_accuracy: 0.9333 - 64ms/epoch - 21ms/step
# Epoch 164/200
# 3/3 - 0s - loss: 0.0267 - accuracy: 0.9889 - val_loss: 0.1660 - val_accuracy: 0.9333 - 56ms/epoch - 19ms/step
# Epoch 165/200
# 3/3 - 0s - loss: 0.0374 - accuracy: 0.9778 - val_loss: 0.1582 - val_accuracy: 0.9333 - 72ms/epoch - 24ms/step
# Epoch 166/200
# 3/3 - 0s - loss: 0.0686 - accuracy: 0.9778 - val_loss: 0.1715 - val_accuracy: 0.9333 - 73ms/epoch - 24ms/step
# Epoch 167/200
# 3/3 - 0s - loss: 0.0158 - accuracy: 1.0000 - val_loss: 0.1826 - val_accuracy: 0.9333 - 83ms/epoch - 28ms/step
# Epoch 168/200
# 3/3 - 0s - loss: 0.0147 - accuracy: 1.0000 - val_loss: 0.1905 - val_accuracy: 0.9333 - 93ms/epoch - 31ms/step
# Epoch 169/200
# 3/3 - 0s - loss: 0.0158 - accuracy: 1.0000 - val_loss: 0.2007 - val_accuracy: 0.9333 - 102ms/epoch - 34ms/step
# Epoch 170/200
# 3/3 - 0s - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.2048 - val_accuracy: 0.9333 - 79ms/epoch - 26ms/step
# Epoch 171/200
# 3/3 - 0s - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.2051 - val_accuracy: 0.9333 - 75ms/epoch - 25ms/step
# Epoch 172/200
# 3/3 - 0s - loss: 0.0139 - accuracy: 1.0000 - val_loss: 0.2036 - val_accuracy: 0.9333 - 73ms/epoch - 24ms/step
# Epoch 173/200
# 3/3 - 0s - loss: 0.0131 - accuracy: 1.0000 - val_loss: 0.2028 - val_accuracy: 0.9333 - 64ms/epoch - 21ms/step
# Epoch 174/200
# 3/3 - 0s - loss: 0.1018 - accuracy: 0.9778 - val_loss: 0.2061 - val_accuracy: 0.9333 - 75ms/epoch - 25ms/step
# Epoch 175/200
# 3/3 - 0s - loss: 0.0376 - accuracy: 0.9889 - val_loss: 0.2499 - val_accuracy: 0.9333 - 67ms/epoch - 22ms/step
# Epoch 176/200
# 3/3 - 0s - loss: 0.0456 - accuracy: 0.9889 - val_loss: 0.3500 - val_accuracy: 0.9000 - 73ms/epoch - 24ms/step
# Epoch 177/200
# 3/3 - 0s - loss: 0.0322 - accuracy: 1.0000 - val_loss: 0.3799 - val_accuracy: 0.9000 - 65ms/epoch - 22ms/step
# Epoch 178/200
# 3/3 - 0s - loss: 0.0270 - accuracy: 1.0000 - val_loss: 0.3617 - val_accuracy: 0.9000 - 74ms/epoch - 25ms/step
# Epoch 179/200
# 3/3 - 0s - loss: 0.0251 - accuracy: 0.9889 - val_loss: 0.3282 - val_accuracy: 0.9000 - 66ms/epoch - 22ms/step
# Epoch 180/200
# 3/3 - 0s - loss: 0.0253 - accuracy: 1.0000 - val_loss: 0.2870 - val_accuracy: 0.9333 - 67ms/epoch - 22ms/step
# Epoch 181/200
# 3/3 - 0s - loss: 0.0175 - accuracy: 1.0000 - val_loss: 0.2325 - val_accuracy: 0.9333 - 70ms/epoch - 23ms/step
# Epoch 182/200
# 3/3 - 0s - loss: 0.0228 - accuracy: 1.0000 - val_loss: 0.1902 - val_accuracy: 0.9333 - 68ms/epoch - 23ms/step
# Epoch 183/200
# 3/3 - 0s - loss: 0.0118 - accuracy: 1.0000 - val_loss: 0.1640 - val_accuracy: 0.9667 - 75ms/epoch - 25ms/step
# Epoch 184/200
# 3/3 - 0s - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.1453 - val_accuracy: 0.9667 - 58ms/epoch - 19ms/step
# Epoch 185/200
# 3/3 - 0s - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.1304 - val_accuracy: 0.9667 - 70ms/epoch - 23ms/step
# Epoch 186/200
# 3/3 - 0s - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.1191 - val_accuracy: 0.9667 - 72ms/epoch - 24ms/step
# Epoch 187/200
# 3/3 - 0s - loss: 0.0142 - accuracy: 1.0000 - val_loss: 0.1074 - val_accuracy: 0.9667 - 59ms/epoch - 20ms/step
# Epoch 188/200
# 3/3 - 0s - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0935 - val_accuracy: 0.9667 - 63ms/epoch - 21ms/step
# Epoch 189/200
# 3/3 - 0s - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.0870 - val_accuracy: 0.9667 - 67ms/epoch - 22ms/step
# Epoch 190/200
# 3/3 - 0s - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.0816 - val_accuracy: 0.9667 - 63ms/epoch - 21ms/step
# Epoch 191/200
# 3/3 - 0s - loss: 0.0131 - accuracy: 1.0000 - val_loss: 0.0814 - val_accuracy: 0.9667 - 59ms/epoch - 20ms/step
# Epoch 192/200
# 3/3 - 0s - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.0872 - val_accuracy: 0.9667 - 61ms/epoch - 20ms/step
# Epoch 193/200
# 3/3 - 0s - loss: 0.0178 - accuracy: 1.0000 - val_loss: 0.0915 - val_accuracy: 0.9667 - 67ms/epoch - 22ms/step
# Epoch 194/200
# 3/3 - 0s - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.0970 - val_accuracy: 0.9667 - 66ms/epoch - 22ms/step
# Epoch 195/200
# 3/3 - 0s - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.1085 - val_accuracy: 0.9667 - 73ms/epoch - 24ms/step
# Epoch 196/200
# 3/3 - 0s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.1189 - val_accuracy: 0.9667 - 87ms/epoch - 29ms/step
# Epoch 197/200
# 3/3 - 0s - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.1251 - val_accuracy: 0.9667 - 67ms/epoch - 22ms/step
# Epoch 198/200
# 3/3 - 0s - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1271 - val_accuracy: 0.9667 - 70ms/epoch - 23ms/step
# Epoch 199/200
# 3/3 - 0s - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.1272 - val_accuracy: 0.9667 - 66ms/epoch - 22ms/step
# Epoch 200/200
# 3/3 - 0s - loss: 0.0166 - accuracy: 1.0000 - val_loss: 0.1247 - val_accuracy: 0.9667 - 64ms/epoch - 21ms/step

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
def plot_metric(history, metric):
    train_metrics = history.history[metric]
    val_metrics = history.history['val_'+metric]
    epochs = range(1, len(train_metrics) + 1)
    plt.plot(epochs, train_metrics)
    plt.plot(epochs, val_metrics)
    plt.title('Training and validation '+ metric)
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend(["train_"+metric, 'val_'+metric])
    plt.show()

# %%
plot_metric(batched_history, 'accuracy')

# %%
plot_metric(batched_history, 'loss')

# %%
batched_model.evaluate(X_test, y_test, verbose=2)
# Out:
# 1/1 - 0s - loss: 0.1151 - accuracy: 0.9333 - 34ms/epoch - 34ms/step
# [0.11509599536657333, 0.9333333373069763]
